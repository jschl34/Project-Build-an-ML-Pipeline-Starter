# %%
# !pip install wandb==0.16.0
# !pip install pandas-profiling==3.6.2
# !pip install pandas==1.2
# Out:
# Requirement already satisfied: wandb==0.16.0 in /opt/anaconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (0.16.0)
# Requirement already satisfied: Click!=8.0.0,>=7.1 in /opt/anaconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from wandb==0.16.0) (8.1.7)
# Requirement already satisfied: GitPython!=3.1.29,>=1.0.0 in /opt/anaconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from wandb==0.16.0) (3.1.43)
# Requirement already satisfied: requests<3,>=2.0.0 in /opt/anaconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from wandb==0.16.0) (2.28.2)
# Requirement already satisfied: psutil>=5.0.0 in /opt/anaconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from wandb==0.16.0) (6.1.0)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /opt/anaconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from wandb==0.16.0) (2.18.0)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /opt/anaconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from wandb==0.16.0) (0.4.0)
# Requirement already satisfied: PyYAML in /opt/anaconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from wandb==0.16.0) (6.0.2)
# Requirement already satisfied: setproctitle in /opt/anaconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from wandb==0.16.0) (1.3.3)
# Requirement already satisfied: setuptools in /opt/anaconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from wandb==0.16.0) (75.3.0)
# Requirement already satisfied: appdirs>=1.4.3 in /opt/anaconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from wandb==0.16.0) (1.4.4)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.19.0 in /opt/anaconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from wandb==0.16.0) (4.25.5)
# Requirement already satisfied: six>=1.4.0 in /opt/anaconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from docker-pycreds>=0.4.0->wandb==0.16.0) (1.16.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/anaconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from GitPython!=3.1.29,>=1.0.0->wandb==0.16.0) (4.0.11)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb==0.16.0) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb==0.16.0) (3.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/anaconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb==0.16.0) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb==0.16.0) (2024.8.30)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/anaconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb==0.16.0) (5.0.1)
# Requirement already satisfied: pandas-profiling==3.6.2 in /opt/anaconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (3.6.2)
# Requirement already satisfied: scipy<1.10,>=1.4.1 in /opt/anaconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from pandas-profiling==3.6.2) (1.9.3)
# Requirement already satisfied: pandas!=1.4.0,<1.6,>1.1 in /opt/anaconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from pandas-profiling==3.6.2) (1.5.3)
# Requirement already satisfied: matplotlib<3.7,>=3.2 in /opt/anaconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from pandas-profiling==3.6.2) (3.6.3)
# Requirement already satisfied: pydantic<1.11,>=1.8.1 in /opt/anaconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from pandas-profiling==3.6.2) (1.10.19)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in /opt/anaconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from pandas-profiling==3.6.2) (6.0.2)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in /opt/anaconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from pandas-profiling==3.6.2) (3.1.4)
# Requirement already satisfied: visions==0.7.5 in /opt/anaconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from visions[type_image_path]==0.7.5->pandas-profiling==3.6.2) (0.7.5)
# Requirement already satisfied: numpy<1.24,>=1.16.0 in /opt/anaconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from pandas-profiling==3.6.2) (1.23.5)
# Requirement already satisfied: htmlmin==0.1.12 in /opt/anaconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from pandas-profiling==3.6.2) (0.1.12)
# Requirement already satisfied: phik<0.13,>=0.11.1 in /opt/anaconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from pandas-profiling==3.6.2) (0.12.4)
# Requirement already satisfied: requests<2.29,>=2.24.0 in /opt/anaconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from pandas-profiling==3.6.2) (2.28.2)
# Requirement already satisfied: tqdm<4.65,>=4.48.2 in /opt/anaconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from pandas-profiling==3.6.2) (4.64.1)
# Requirement already satisfied: seaborn<0.13,>=0.10.1 in /opt/anaconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from pandas-profiling==3.6.2) (0.12.2)
# Requirement already satisfied: multimethod<1.10,>=1.4 in /opt/anaconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from pandas-profiling==3.6.2) (1.9.1)
# Requirement already satisfied: statsmodels<0.14,>=0.13.2 in /opt/anaconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from pandas-profiling==3.6.2) (0.13.5)
# Requirement already satisfied: typeguard<2.14,>=2.13.2 in /opt/anaconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from pandas-profiling==3.6.2) (2.13.3)
# Requirement already satisfied: attrs>=19.3.0 in /opt/anaconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from visions==0.7.5->visions[type_image_path]==0.7.5->pandas-profiling==3.6.2) (24.2.0)
# Requirement already satisfied: networkx>=2.4 in /opt/anaconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from visions==0.7.5->visions[type_image_path]==0.7.5->pandas-profiling==3.6.2) (3.4.2)
# Requirement already satisfied: tangled-up-in-unicode>=0.0.4 in /opt/anaconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from visions==0.7.5->visions[type_image_path]==0.7.5->pandas-profiling==3.6.2) (0.2.0)
# WARNING: visions 0.7.5 does not provide the extra 'type-image-path'
# Requirement already satisfied: imagehash in /opt/anaconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from visions[type_image_path]==0.7.5->pandas-profiling==3.6.2) (4.3.1)
# Requirement already satisfied: Pillow in /opt/anaconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from visions[type_image_path]==0.7.5->pandas-profiling==3.6.2) (11.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from jinja2<3.2,>=2.11.1->pandas-profiling==3.6.2) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from matplotlib<3.7,>=3.2->pandas-profiling==3.6.2) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from matplotlib<3.7,>=3.2->pandas-profiling==3.6.2) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from matplotlib<3.7,>=3.2->pandas-profiling==3.6.2) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/anaconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from matplotlib<3.7,>=3.2->pandas-profiling==3.6.2) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from matplotlib<3.7,>=3.2->pandas-profiling==3.6.2) (23.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/anaconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from matplotlib<3.7,>=3.2->pandas-profiling==3.6.2) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from matplotlib<3.7,>=3.2->pandas-profiling==3.6.2) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from pandas!=1.4.0,<1.6,>1.1->pandas-profiling==3.6.2) (2023.4)
# Requirement already satisfied: joblib>=0.14.1 in /opt/anaconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from phik<0.13,>=0.11.1->pandas-profiling==3.6.2) (1.4.2)
# Requirement already satisfied: typing-extensions>=4.2.0 in /opt/anaconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from pydantic<1.11,>=1.8.1->pandas-profiling==3.6.2) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from requests<2.29,>=2.24.0->pandas-profiling==3.6.2) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from requests<2.29,>=2.24.0->pandas-profiling==3.6.2) (3.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/anaconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from requests<2.29,>=2.24.0->pandas-profiling==3.6.2) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from requests<2.29,>=2.24.0->pandas-profiling==3.6.2) (2024.8.30)
# Requirement already satisfied: patsy>=0.5.2 in /opt/anaconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from statsmodels<0.14,>=0.13.2->pandas-profiling==3.6.2) (1.0.1)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib<3.7,>=3.2->pandas-profiling==3.6.2) (1.16.0)
# Requirement already satisfied: PyWavelets in /opt/anaconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from imagehash->visions[type_image_path]==0.7.5->pandas-profiling==3.6.2) (1.7.0)
# Collecting pandas==1.2
#   Using cached pandas-1.2.0.tar.gz (5.4 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/anaconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from pandas==1.2) (2.9.0)
# Requirement already satisfied: pytz>=2017.3 in /opt/anaconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from pandas==1.2) (2023.4)
# Requirement already satisfied: numpy>=1.16.5 in /opt/anaconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from pandas==1.2) (1.23.5)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/nyc_airbnb_dev/lib/python3.10/site-packages (from python-dateutil>=2.7.3->pandas==1.2) (1.16.0)
# Building wheels for collected packages: pandas
#   Building wheel for pandas (pyproject.toml) ... error
#   error: subprocess-exited-with-error
#
#   × Building wheel for pandas (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [2231 lines of output]
#       <string>:44: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#       <string>:438: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#       running bdist_wheel
#       running build
#       running build_py
#       creating build/lib.macosx-11.0-arm64-cpython-310/pandas
#       copying pandas/conftest.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas
#       copying pandas/_typing.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas
#       copying pandas/_version.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas
#       copying pandas/__init__.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas
#       copying pandas/_testing.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas
#       copying pandas/testing.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas
#       creating build/lib.macosx-11.0-arm64-cpython-310/pandas/compat
#       copying pandas/compat/_optional.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/compat
#       copying pandas/compat/__init__.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/compat
#       copying pandas/compat/chainmap.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/compat
#       copying pandas/compat/pickle_compat.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/compat
#       creating build/lib.macosx-11.0-arm64-cpython-310/pandas/core
#       copying pandas/core/accessor.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core
#       copying pandas/core/nanops.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core
#       copying pandas/core/missing.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core
#       copying pandas/core/aggregation.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core
#       copying pandas/core/algorithms.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core
#       copying pandas/core/resample.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core
#       copying pandas/core/index.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core
#       copying pandas/core/arraylike.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core
#       copying pandas/core/construction.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core
#       copying pandas/core/config_init.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core
#       copying pandas/core/flags.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core
#       copying pandas/core/generic.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core
#       copying pandas/core/series.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core
#       copying pandas/core/sorting.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core
#       copying pandas/core/__init__.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core
#       copying pandas/core/indexers.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core
#       copying pandas/core/api.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core
#       copying pandas/core/common.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core
#       copying pandas/core/frame.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core
#       copying pandas/core/shared_docs.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core
#       copying pandas/core/indexing.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core
#       copying pandas/core/base.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core
#       copying pandas/core/apply.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core
#       creating build/lib.macosx-11.0-arm64-cpython-310/pandas/util
#       copying pandas/util/_depr_module.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/util
#       copying pandas/util/_test_decorators.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/util
#       copying pandas/util/_validators.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/util
#       copying pandas/util/_print_versions.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/util
#       copying pandas/util/__init__.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/util
#       copying pandas/util/_decorators.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/util
#       copying pandas/util/_doctools.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/util
#       copying pandas/util/testing.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/util
#       copying pandas/util/_exceptions.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/util
#       copying pandas/util/_tester.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/util
#       creating build/lib.macosx-11.0-arm64-cpython-310/pandas/io
#       copying pandas/io/orc.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/io
#       copying pandas/io/feather_format.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/io
#       copying pandas/io/parquet.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/io
#       copying pandas/io/pytables.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/io
#       copying pandas/io/html.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/io
#       copying pandas/io/__init__.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/io
#       copying pandas/io/clipboards.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/io
#       copying pandas/io/parsers.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/io
#       copying pandas/io/api.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/io
#       copying pandas/io/common.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/io
#       copying pandas/io/date_converters.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/io
#       copying pandas/io/pickle.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/io
#       copying pandas/io/sql.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/io
#       copying pandas/io/stata.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/io
#       copying pandas/io/gbq.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/io
#       copying pandas/io/spss.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/io
#       creating build/lib.macosx-11.0-arm64-cpython-310/pandas/tseries
#       copying pandas/tseries/__init__.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tseries
#       copying pandas/tseries/api.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tseries
#       copying pandas/tseries/offsets.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tseries
#       copying pandas/tseries/frequencies.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tseries
#       copying pandas/tseries/holiday.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tseries
#       creating build/lib.macosx-11.0-arm64-cpython-310/pandas/tests
#       copying pandas/tests/test_optional_dependency.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests
#       copying pandas/tests/test_expressions.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests
#       copying pandas/tests/test_register_accessor.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests
#       copying pandas/tests/test_common.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests
#       copying pandas/tests/test_downstream.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests
#       copying pandas/tests/test_errors.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests
#       copying pandas/tests/test_sorting.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests
#       copying pandas/tests/test_aggregation.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests
#       copying pandas/tests/__init__.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests
#       copying pandas/tests/test_nanops.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests
#       copying pandas/tests/test_take.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests
#       copying pandas/tests/test_algos.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests
#       copying pandas/tests/test_multilevel.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests
#       copying pandas/tests/test_flags.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests
#       copying pandas/tests/test_strings.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests
#       creating build/lib.macosx-11.0-arm64-cpython-310/pandas/_libs
#       copying pandas/_libs/__init__.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/_libs
#       creating build/lib.macosx-11.0-arm64-cpython-310/pandas/plotting
#       copying pandas/plotting/__init__.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/plotting
#       copying pandas/plotting/_core.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/plotting
#       copying pandas/plotting/_misc.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/plotting
#       creating build/lib.macosx-11.0-arm64-cpython-310/pandas/arrays
#       copying pandas/arrays/__init__.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/arrays
#       creating build/lib.macosx-11.0-arm64-cpython-310/pandas/api
#       copying pandas/api/__init__.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/api
#       creating build/lib.macosx-11.0-arm64-cpython-310/pandas/errors
#       copying pandas/errors/__init__.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/errors
#       creating build/lib.macosx-11.0-arm64-cpython-310/pandas/_config
#       copying pandas/_config/config.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/_config
#       copying pandas/_config/__init__.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/_config
#       copying pandas/_config/display.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/_config
#       copying pandas/_config/localization.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/_config
#       copying pandas/_config/dates.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/_config
#       creating build/lib.macosx-11.0-arm64-cpython-310/pandas/compat/numpy
#       copying pandas/compat/numpy/__init__.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/compat/numpy
#       copying pandas/compat/numpy/function.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/compat/numpy
#       creating build/lib.macosx-11.0-arm64-cpython-310/pandas/core/reshape
#       copying pandas/core/reshape/tile.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/reshape
#       copying pandas/core/reshape/merge.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/reshape
#       copying pandas/core/reshape/concat.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/reshape
#       copying pandas/core/reshape/util.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/reshape
#       copying pandas/core/reshape/reshape.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/reshape
#       copying pandas/core/reshape/__init__.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/reshape
#       copying pandas/core/reshape/api.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/reshape
#       copying pandas/core/reshape/melt.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/reshape
#       copying pandas/core/reshape/pivot.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/reshape
#       creating build/lib.macosx-11.0-arm64-cpython-310/pandas/core/strings
#       copying pandas/core/strings/accessor.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/strings
#       copying pandas/core/strings/object_array.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/strings
#       copying pandas/core/strings/__init__.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/strings
#       copying pandas/core/strings/base.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/strings
#       creating build/lib.macosx-11.0-arm64-cpython-310/pandas/core/tools
#       copying pandas/core/tools/timedeltas.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/tools
#       copying pandas/core/tools/datetimes.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/tools
#       copying pandas/core/tools/__init__.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/tools
#       copying pandas/core/tools/times.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/tools
#       copying pandas/core/tools/numeric.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/tools
#       creating build/lib.macosx-11.0-arm64-cpython-310/pandas/core/util
#       copying pandas/core/util/__init__.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/util
#       copying pandas/core/util/hashing.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/util
#       copying pandas/core/util/numba_.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/util
#       creating build/lib.macosx-11.0-arm64-cpython-310/pandas/core/array_algos
#       copying pandas/core/array_algos/transforms.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/array_algos
#       copying pandas/core/array_algos/__init__.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/array_algos
#       copying pandas/core/array_algos/masked_reductions.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/array_algos
#       copying pandas/core/array_algos/replace.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/array_algos
#       creating build/lib.macosx-11.0-arm64-cpython-310/pandas/core/dtypes
#       copying pandas/core/dtypes/cast.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/dtypes
#       copying pandas/core/dtypes/missing.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/dtypes
#       copying pandas/core/dtypes/concat.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/dtypes
#       copying pandas/core/dtypes/generic.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/dtypes
#       copying pandas/core/dtypes/__init__.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/dtypes
#       copying pandas/core/dtypes/dtypes.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/dtypes
#       copying pandas/core/dtypes/api.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/dtypes
#       copying pandas/core/dtypes/common.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/dtypes
#       copying pandas/core/dtypes/inference.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/dtypes
#       copying pandas/core/dtypes/base.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/dtypes
#       creating build/lib.macosx-11.0-arm64-cpython-310/pandas/core/groupby
#       copying pandas/core/groupby/categorical.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/groupby
#       copying pandas/core/groupby/generic.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/groupby
#       copying pandas/core/groupby/__init__.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/groupby
#       copying pandas/core/groupby/ops.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/groupby
#       copying pandas/core/groupby/grouper.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/groupby
#       copying pandas/core/groupby/groupby.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/groupby
#       copying pandas/core/groupby/numba_.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/groupby
#       copying pandas/core/groupby/base.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/groupby
#       creating build/lib.macosx-11.0-arm64-cpython-310/pandas/core/internals
#       copying pandas/core/internals/concat.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/internals
#       copying pandas/core/internals/construction.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/internals
#       copying pandas/core/internals/__init__.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/internals
#       copying pandas/core/internals/ops.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/internals
#       copying pandas/core/internals/blocks.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/internals
#       copying pandas/core/internals/managers.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/internals
#       creating build/lib.macosx-11.0-arm64-cpython-310/pandas/core/computation
#       copying pandas/core/computation/parsing.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/computation
#       copying pandas/core/computation/check.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/computation
#       copying pandas/core/computation/align.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/computation
#       copying pandas/core/computation/pytables.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/computation
#       copying pandas/core/computation/engines.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/computation
#       copying pandas/core/computation/expressions.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/computation
#       copying pandas/core/computation/__init__.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/computation
#       copying pandas/core/computation/api.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/computation
#       copying pandas/core/computation/ops.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/computation
#       copying pandas/core/computation/common.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/computation
#       copying pandas/core/computation/eval.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/computation
#       copying pandas/core/computation/scope.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/computation
#       copying pandas/core/computation/expr.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/computation
#       creating build/lib.macosx-11.0-arm64-cpython-310/pandas/core/window
#       copying pandas/core/window/ewm.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/window
#       copying pandas/core/window/__init__.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/window
#       copying pandas/core/window/rolling.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/window
#       copying pandas/core/window/indexers.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/window
#       copying pandas/core/window/common.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/window
#       copying pandas/core/window/numba_.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/window
#       copying pandas/core/window/expanding.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/window
#       creating build/lib.macosx-11.0-arm64-cpython-310/pandas/core/arrays
#       copying pandas/core/arrays/floating.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/arrays
#       copying pandas/core/arrays/categorical.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/arrays
#       copying pandas/core/arrays/_arrow_utils.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/arrays
#       copying pandas/core/arrays/interval.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/arrays
#       copying pandas/core/arrays/timedeltas.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/arrays
#       copying pandas/core/arrays/datetimes.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/arrays
#       copying pandas/core/arrays/string_.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/arrays
#       copying pandas/core/arrays/__init__.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/arrays
#       copying pandas/core/arrays/numpy_.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/arrays
#       copying pandas/core/arrays/_ranges.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/arrays
#       copying pandas/core/arrays/string_arrow.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/arrays
#       copying pandas/core/arrays/boolean.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/arrays
#       copying pandas/core/arrays/integer.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/arrays
#       copying pandas/core/arrays/masked.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/arrays
#       copying pandas/core/arrays/period.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/arrays
#       copying pandas/core/arrays/numeric.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/arrays
#       copying pandas/core/arrays/datetimelike.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/arrays
#       copying pandas/core/arrays/base.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/arrays
#       copying pandas/core/arrays/_mixins.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/arrays
#       creating build/lib.macosx-11.0-arm64-cpython-310/pandas/core/ops
#       copying pandas/core/ops/array_ops.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/ops
#       copying pandas/core/ops/roperator.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/ops
#       copying pandas/core/ops/missing.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/ops
#       copying pandas/core/ops/methods.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/ops
#       copying pandas/core/ops/dispatch.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/ops
#       copying pandas/core/ops/invalid.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/ops
#       copying pandas/core/ops/__init__.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/ops
#       copying pandas/core/ops/docstrings.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/ops
#       copying pandas/core/ops/mask_ops.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/ops
#       copying pandas/core/ops/common.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/ops
#       creating build/lib.macosx-11.0-arm64-cpython-310/pandas/core/sparse
#       copying pandas/core/sparse/__init__.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/sparse
#       copying pandas/core/sparse/api.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/sparse
#       creating build/lib.macosx-11.0-arm64-cpython-310/pandas/core/indexes
#       copying pandas/core/indexes/accessors.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/indexes
#       copying pandas/core/indexes/interval.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/indexes
#       copying pandas/core/indexes/timedeltas.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/indexes
#       copying pandas/core/indexes/range.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/indexes
#       copying pandas/core/indexes/datetimes.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/indexes
#       copying pandas/core/indexes/multi.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/indexes
#       copying pandas/core/indexes/__init__.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/indexes
#       copying pandas/core/indexes/api.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/indexes
#       copying pandas/core/indexes/period.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/indexes
#       copying pandas/core/indexes/frozen.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/indexes
#       copying pandas/core/indexes/extension.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/indexes
#       copying pandas/core/indexes/numeric.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/indexes
#       copying pandas/core/indexes/datetimelike.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/indexes
#       copying pandas/core/indexes/base.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/indexes
#       copying pandas/core/indexes/category.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/indexes
#       creating build/lib.macosx-11.0-arm64-cpython-310/pandas/core/arrays/sparse
#       copying pandas/core/arrays/sparse/accessor.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/arrays/sparse
#       copying pandas/core/arrays/sparse/scipy_sparse.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/arrays/sparse
#       copying pandas/core/arrays/sparse/dtype.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/arrays/sparse
#       copying pandas/core/arrays/sparse/__init__.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/arrays/sparse
#       copying pandas/core/arrays/sparse/array.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/core/arrays/sparse
#       creating build/lib.macosx-11.0-arm64-cpython-310/pandas/io/formats
#       copying pandas/io/formats/console.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/io/formats
#       copying pandas/io/formats/style.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/io/formats
#       copying pandas/io/formats/html.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/io/formats
#       copying pandas/io/formats/__init__.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/io/formats
#       copying pandas/io/formats/format.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/io/formats
#       copying pandas/io/formats/excel.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/io/formats
#       copying pandas/io/formats/css.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/io/formats
#       copying pandas/io/formats/_color_data.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/io/formats
#       copying pandas/io/formats/csvs.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/io/formats
#       copying pandas/io/formats/string.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/io/formats
#       copying pandas/io/formats/info.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/io/formats
#       copying pandas/io/formats/latex.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/io/formats
#       copying pandas/io/formats/printing.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/io/formats
#       creating build/lib.macosx-11.0-arm64-cpython-310/pandas/io/excel
#       copying pandas/io/excel/_openpyxl.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/io/excel
#       copying pandas/io/excel/_base.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/io/excel
#       copying pandas/io/excel/_xlrd.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/io/excel
#       copying pandas/io/excel/__init__.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/io/excel
#       copying pandas/io/excel/_pyxlsb.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/io/excel
#       copying pandas/io/excel/_odswriter.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/io/excel
#       copying pandas/io/excel/_util.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/io/excel
#       copying pandas/io/excel/_odfreader.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/io/excel
#       copying pandas/io/excel/_xlwt.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/io/excel
#       copying pandas/io/excel/_xlsxwriter.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/io/excel
#       creating build/lib.macosx-11.0-arm64-cpython-310/pandas/io/json
#       copying pandas/io/json/_json.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/io/json
#       copying pandas/io/json/_normalize.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/io/json
#       copying pandas/io/json/_table_schema.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/io/json
#       copying pandas/io/json/__init__.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/io/json
#       creating build/lib.macosx-11.0-arm64-cpython-310/pandas/io/sas
#       copying pandas/io/sas/sas7bdat.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/io/sas
#       copying pandas/io/sas/sas_constants.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/io/sas
#       copying pandas/io/sas/sasreader.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/io/sas
#       copying pandas/io/sas/__init__.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/io/sas
#       copying pandas/io/sas/sas_xport.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/io/sas
#       creating build/lib.macosx-11.0-arm64-cpython-310/pandas/io/clipboard
#       copying pandas/io/clipboard/__init__.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/io/clipboard
#       creating build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/series
#       copying pandas/tests/series/test_logical_ops.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/series
#       copying pandas/tests/series/test_reductions.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/series
#       copying pandas/tests/series/test_constructors.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/series
#       copying pandas/tests/series/test_missing.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/series
#       copying pandas/tests/series/test_unary.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/series
#       copying pandas/tests/series/test_cumulative.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/series
#       copying pandas/tests/series/__init__.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/series
#       copying pandas/tests/series/test_subclass.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/series
#       copying pandas/tests/series/test_repr.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/series
#       copying pandas/tests/series/test_iteration.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/series
#       copying pandas/tests/series/test_ufunc.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/series
#       copying pandas/tests/series/test_validate.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/series
#       copying pandas/tests/series/test_duplicates.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/series
#       copying pandas/tests/series/test_npfuncs.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/series
#       copying pandas/tests/series/test_api.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/series
#       copying pandas/tests/series/test_arithmetic.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/series
#       copying pandas/tests/series/test_dtypes.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/series
#       creating build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/reshape
#       copying pandas/tests/reshape/test_pivot_multilevel.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/reshape
#       copying pandas/tests/reshape/test_cut.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/reshape
#       copying pandas/tests/reshape/test_get_dummies.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/reshape
#       copying pandas/tests/reshape/test_union_categoricals.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/reshape
#       copying pandas/tests/reshape/test_qcut.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/reshape
#       copying pandas/tests/reshape/__init__.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/reshape
#       copying pandas/tests/reshape/test_pivot.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/reshape
#       copying pandas/tests/reshape/test_util.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/reshape
#       copying pandas/tests/reshape/test_melt.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/reshape
#       copying pandas/tests/reshape/test_crosstab.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/reshape
#       creating build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/tools
#       copying pandas/tests/tools/test_to_time.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/tools
#       copying pandas/tests/tools/__init__.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/tools
#       copying pandas/tests/tools/test_to_timedelta.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/tools
#       copying pandas/tests/tools/test_to_datetime.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/tools
#       copying pandas/tests/tools/test_to_numeric.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/tools
#       creating build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/extension
#       copying pandas/tests/extension/test_external_block.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/extension
#       copying pandas/tests/extension/test_period.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/extension
#       copying pandas/tests/extension/conftest.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/extension
#       copying pandas/tests/extension/test_common.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/extension
#       copying pandas/tests/extension/test_sparse.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/extension
#       copying pandas/tests/extension/test_floating.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/extension
#       copying pandas/tests/extension/test_string.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/extension
#       copying pandas/tests/extension/test_categorical.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/extension
#       copying pandas/tests/extension/test_boolean.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/extension
#       copying pandas/tests/extension/__init__.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/extension
#       copying pandas/tests/extension/test_interval.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/extension
#       copying pandas/tests/extension/test_datetime.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/extension
#       copying pandas/tests/extension/test_integer.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/extension
#       copying pandas/tests/extension/test_numpy.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/extension
#       creating build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/resample
#       copying pandas/tests/resample/conftest.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/resample
#       copying pandas/tests/resample/test_resampler_grouper.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/resample
#       copying pandas/tests/resample/__init__.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/resample
#       copying pandas/tests/resample/test_timedelta.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/resample
#       copying pandas/tests/resample/test_deprecated.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/resample
#       copying pandas/tests/resample/test_period_index.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/resample
#       copying pandas/tests/resample/test_datetime_index.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/resample
#       copying pandas/tests/resample/test_base.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/resample
#       copying pandas/tests/resample/test_time_grouper.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/resample
#       copying pandas/tests/resample/test_resample_api.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/resample
#       creating build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/util
#       copying pandas/tests/util/test_deprecate_nonkeyword_arguments.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/util
#       copying pandas/tests/util/test_validate_args_and_kwargs.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/util
#       copying pandas/tests/util/test_assert_series_equal.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/util
#       copying pandas/tests/util/conftest.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/util
#       copying pandas/tests/util/test_safe_import.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/util
#       copying pandas/tests/util/test_assert_frame_equal.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/util
#       copying pandas/tests/util/test_show_versions.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/util
#       copying pandas/tests/util/test_assert_interval_array_equal.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/util
#       copying pandas/tests/util/__init__.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/util
#       copying pandas/tests/util/test_util.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/util
#       copying pandas/tests/util/test_assert_index_equal.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/util
#       copying pandas/tests/util/test_validate_args.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/util
#       copying pandas/tests/util/test_validate_kwargs.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/util
#       copying pandas/tests/util/test_assert_categorical_equal.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/util
#       copying pandas/tests/util/test_assert_numpy_array_equal.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/util
#       copying pandas/tests/util/test_assert_extension_array_equal.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/util
#       copying pandas/tests/util/test_deprecate.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/util
#       copying pandas/tests/util/test_hashing.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/util
#       copying pandas/tests/util/test_assert_produces_warning.py -> build/lib.macosx-11.0-arm64-cpython-310/pandas/tests/util
# ...
#       pandas/_libs/window/aggregations.cpp:38525:21: warning: fallthrough annotation in unreachable code [-Wunreachable-code-fallthrough]
#        38525 |                     CYTHON_FALLTHROUGH;
#              |                     ^
#       pandas/_libs/window/aggregations.cpp:383:34: note: expanded from macro 'CYTHON_FALLTHROUGH'
#         383 |       #define CYTHON_FALLTHROUGH __attribute__((fallthrough))
#             |                                  ^
#       pandas/_libs/window/aggregations.cpp:38536:21: warning: fallthrough annotation in unreachable code [-Wunreachable-code-fallthrough]
#        38536 |                     CYTHON_FALLTHROUGH;
#              |                     ^
#       pandas/_libs/window/aggregations.cpp:383:34: note: expanded from macro 'CYTHON_FALLTHROUGH'
#         383 |       #define CYTHON_FALLTHROUGH __attribute__((fallthrough))
#             |                                  ^
#       2 warnings generated.
#       clang++ -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/anaconda3/envs/nyc_airbnb_dev/include -arch arm64 -fPIC -O2 -isystem /opt/anaconda3/envs/nyc_airbnb_dev/include -arch arm64 -bundle -undefined dynamic_lookup build/temp.macosx-11.0-arm64-cpython-310/pandas/_libs/window/aggregations.o -o build/lib.macosx-11.0-arm64-cpython-310/pandas/_libs/window/aggregations.cpython-310-darwin.so
#       building 'pandas._libs.window.indexers' extension
#       clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/anaconda3/envs/nyc_airbnb_dev/include -arch arm64 -fPIC -O2 -isystem /opt/anaconda3/envs/nyc_airbnb_dev/include -arch arm64 -DNPY_NO_DEPRECATED_API=0 -I/private/var/folders/p1/jp0nz1s934z81bhr01h6z0lr0000gn/T/pip-build-env-b44mk95b/overlay/lib/python3.10/site-packages/numpy/_core/include -I/opt/anaconda3/envs/nyc_airbnb_dev/include/python3.10 -c pandas/_libs/window/indexers.c -o build/temp.macosx-11.0-arm64-cpython-310/pandas/_libs/window/indexers.o -Wno-error=unreachable-code
#       pandas/_libs/window/indexers.c:21618:21: warning: fallthrough annotation in unreachable code [-Wunreachable-code-fallthrough]
#        21618 |                     CYTHON_FALLTHROUGH;
#              |                     ^
#       pandas/_libs/window/indexers.c:377:34: note: expanded from macro 'CYTHON_FALLTHROUGH'
#         377 |       #define CYTHON_FALLTHROUGH __attribute__((fallthrough))
#             |                                  ^
#       pandas/_libs/window/indexers.c:21629:21: warning: fallthrough annotation in unreachable code [-Wunreachable-code-fallthrough]
#        21629 |                     CYTHON_FALLTHROUGH;
#              |                     ^
#       pandas/_libs/window/indexers.c:377:34: note: expanded from macro 'CYTHON_FALLTHROUGH'
#         377 |       #define CYTHON_FALLTHROUGH __attribute__((fallthrough))
#             |                                  ^
#       2 warnings generated.
#       clang -bundle -undefined dynamic_lookup -Wl,-rpath,/opt/anaconda3/envs/nyc_airbnb_dev/lib -L/opt/anaconda3/envs/nyc_airbnb_dev/lib -Wl,-rpath,/opt/anaconda3/envs/nyc_airbnb_dev/lib -L/opt/anaconda3/envs/nyc_airbnb_dev/lib build/temp.macosx-11.0-arm64-cpython-310/pandas/_libs/window/indexers.o -o build/lib.macosx-11.0-arm64-cpython-310/pandas/_libs/window/indexers.cpython-310-darwin.so
#       ld: warning: duplicate -rpath '/opt/anaconda3/envs/nyc_airbnb_dev/lib' ignored
#       building 'pandas._libs.writers' extension
#       clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/anaconda3/envs/nyc_airbnb_dev/include -arch arm64 -fPIC -O2 -isystem /opt/anaconda3/envs/nyc_airbnb_dev/include -arch arm64 -DNPY_NO_DEPRECATED_API=0 -I/private/var/folders/p1/jp0nz1s934z81bhr01h6z0lr0000gn/T/pip-build-env-b44mk95b/overlay/lib/python3.10/site-packages/numpy/_core/include -I/opt/anaconda3/envs/nyc_airbnb_dev/include/python3.10 -c pandas/_libs/writers.c -o build/temp.macosx-11.0-arm64-cpython-310/pandas/_libs/writers.o -Wno-error=unreachable-code
#       pandas/_libs/writers.c:24445:21: warning: fallthrough annotation in unreachable code [-Wunreachable-code-fallthrough]
#        24445 |                     CYTHON_FALLTHROUGH;
#              |                     ^
#       pandas/_libs/writers.c:377:34: note: expanded from macro 'CYTHON_FALLTHROUGH'
#         377 |       #define CYTHON_FALLTHROUGH __attribute__((fallthrough))
#             |                                  ^
#       pandas/_libs/writers.c:24456:21: warning: fallthrough annotation in unreachable code [-Wunreachable-code-fallthrough]
#        24456 |                     CYTHON_FALLTHROUGH;
#              |                     ^
#       pandas/_libs/writers.c:377:34: note: expanded from macro 'CYTHON_FALLTHROUGH'
#         377 |       #define CYTHON_FALLTHROUGH __attribute__((fallthrough))
#             |                                  ^
#       2 warnings generated.
#       clang -bundle -undefined dynamic_lookup -Wl,-rpath,/opt/anaconda3/envs/nyc_airbnb_dev/lib -L/opt/anaconda3/envs/nyc_airbnb_dev/lib -Wl,-rpath,/opt/anaconda3/envs/nyc_airbnb_dev/lib -L/opt/anaconda3/envs/nyc_airbnb_dev/lib build/temp.macosx-11.0-arm64-cpython-310/pandas/_libs/writers.o -o build/lib.macosx-11.0-arm64-cpython-310/pandas/_libs/writers.cpython-310-darwin.so
#       ld: warning: duplicate -rpath '/opt/anaconda3/envs/nyc_airbnb_dev/lib' ignored
#       building 'pandas.io.sas._sas' extension
#       creating build/temp.macosx-11.0-arm64-cpython-310/pandas/io/sas
#       clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/anaconda3/envs/nyc_airbnb_dev/include -arch arm64 -fPIC -O2 -isystem /opt/anaconda3/envs/nyc_airbnb_dev/include -arch arm64 -DNPY_NO_DEPRECATED_API=0 -I/private/var/folders/p1/jp0nz1s934z81bhr01h6z0lr0000gn/T/pip-build-env-b44mk95b/overlay/lib/python3.10/site-packages/numpy/_core/include -I/opt/anaconda3/envs/nyc_airbnb_dev/include/python3.10 -c pandas/io/sas/sas.c -o build/temp.macosx-11.0-arm64-cpython-310/pandas/io/sas/sas.o -Wno-error=unreachable-code
#       pandas/io/sas/sas.c:23093:21: warning: fallthrough annotation in unreachable code [-Wunreachable-code-fallthrough]
#        23093 |                     CYTHON_FALLTHROUGH;
#              |                     ^
#       pandas/io/sas/sas.c:370:34: note: expanded from macro 'CYTHON_FALLTHROUGH'
#         370 |       #define CYTHON_FALLTHROUGH __attribute__((fallthrough))
#             |                                  ^
#       pandas/io/sas/sas.c:23104:21: warning: fallthrough annotation in unreachable code [-Wunreachable-code-fallthrough]
#        23104 |                     CYTHON_FALLTHROUGH;
#              |                     ^
#       pandas/io/sas/sas.c:370:34: note: expanded from macro 'CYTHON_FALLTHROUGH'
#         370 |       #define CYTHON_FALLTHROUGH __attribute__((fallthrough))
#             |                                  ^
#       2 warnings generated.
#       clang -bundle -undefined dynamic_lookup -Wl,-rpath,/opt/anaconda3/envs/nyc_airbnb_dev/lib -L/opt/anaconda3/envs/nyc_airbnb_dev/lib -Wl,-rpath,/opt/anaconda3/envs/nyc_airbnb_dev/lib -L/opt/anaconda3/envs/nyc_airbnb_dev/lib build/temp.macosx-11.0-arm64-cpython-310/pandas/io/sas/sas.o -o build/lib.macosx-11.0-arm64-cpython-310/pandas/io/sas/_sas.cpython-310-darwin.so
#       ld: warning: duplicate -rpath '/opt/anaconda3/envs/nyc_airbnb_dev/lib' ignored
#       building 'pandas._libs.json' extension
#       creating build/temp.macosx-11.0-arm64-cpython-310/pandas/_libs/src/ujson/lib
#       creating build/temp.macosx-11.0-arm64-cpython-310/pandas/_libs/src/ujson/python
#       clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/anaconda3/envs/nyc_airbnb_dev/include -arch arm64 -fPIC -O2 -isystem /opt/anaconda3/envs/nyc_airbnb_dev/include -arch arm64 -DNPY_NO_DEPRECATED_API=0 -Ipandas/_libs/src/ujson/python -Ipandas/_libs/src/ujson/lib -Ipandas/_libs/src/datetime -I/private/var/folders/p1/jp0nz1s934z81bhr01h6z0lr0000gn/T/pip-build-env-b44mk95b/overlay/lib/python3.10/site-packages/numpy/_core/include -I/opt/anaconda3/envs/nyc_airbnb_dev/include/python3.10 -c pandas/_libs/src/ujson/lib/ultrajsondec.c -o build/temp.macosx-11.0-arm64-cpython-310/pandas/_libs/src/ujson/lib/ultrajsondec.o -D_GNU_SOURCE -Wno-error=unreachable-code
#       pandas/_libs/src/ujson/lib/ultrajsondec.c:119:9: warning: variable 'mantSize' set but not used [-Wunused-but-set-variable]
#         119 |     int mantSize = 0;
#             |         ^
#       1 warning generated.
#       clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/anaconda3/envs/nyc_airbnb_dev/include -arch arm64 -fPIC -O2 -isystem /opt/anaconda3/envs/nyc_airbnb_dev/include -arch arm64 -DNPY_NO_DEPRECATED_API=0 -Ipandas/_libs/src/ujson/python -Ipandas/_libs/src/ujson/lib -Ipandas/_libs/src/datetime -I/private/var/folders/p1/jp0nz1s934z81bhr01h6z0lr0000gn/T/pip-build-env-b44mk95b/overlay/lib/python3.10/site-packages/numpy/_core/include -I/opt/anaconda3/envs/nyc_airbnb_dev/include/python3.10 -c pandas/_libs/src/ujson/lib/ultrajsonenc.c -o build/temp.macosx-11.0-arm64-cpython-310/pandas/_libs/src/ujson/lib/ultrajsonenc.o -D_GNU_SOURCE -Wno-error=unreachable-code
#       clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /opt/anaconda3/envs/nyc_airbnb_dev/include -arch arm64 -fPIC -O2 -isystem /opt/anaconda3/envs/nyc_airbnb_dev/include -arch arm64 -DNPY_NO_DEPRECATED_API=0 -Ipandas/_libs/src/ujson/python -Ipandas/_libs/src/ujson/lib -Ipandas/_libs/src/datetime -I/private/var/folders/p1/jp0nz1s934z81bhr01h6z0lr0000gn/T/pip-build-env-b44mk95b/overlay/lib/python3.10/site-packages/numpy/_core/include -I/opt/anaconda3/envs/nyc_airbnb_dev/include/python3.10 -c pandas/_libs/src/ujson/python/JSONtoObj.c -o build/temp.macosx-11.0-arm64-cpython-310/pandas/_libs/src/ujson/python/JSONtoObj.o -D_GNU_SOURCE -Wno-error=unreachable-code
#       pandas/_libs/src/ujson/python/JSONtoObj.c:195:49: warning: incompatible pointer types passing 'PyObject *' (aka 'struct _object *') to parameter of type 'const PyArrayObject *' (aka 'const struct tagPyArrayObject_fields *') [-Wincompatible-pointer-types]
#         195 |         new_data = PyDataMem_RENEW(PyArray_DATA(ret), i * npyarr->elsize);
#             |                                                 ^~~
#       /private/var/folders/p1/jp0nz1s934z81bhr01h6z0lr0000gn/T/pip-build-env-b44mk95b/overlay/lib/python3.10/site-packages/numpy/_core/include/numpy/ndarraytypes.h:1508:35: note: passing argument to parameter 'arr' here
#        1508 | PyArray_DATA(const PyArrayObject *arr)
#             |                                   ^
#       pandas/_libs/src/ujson/python/JSONtoObj.c:260:33: error: no member named 'elsize' in 'struct _PyArray_Descr'
#         260 |         npyarr->elsize = dtype->elsize;
#             |                          ~~~~~  ^
#       pandas/_libs/src/ujson/python/JSONtoObj.c:305:53: warning: incompatible pointer types passing 'PyObject *' (aka 'struct _object *') to parameter of type 'const PyArrayObject *' (aka 'const struct tagPyArrayObject_fields *') [-Wincompatible-pointer-types]
#         305 |             new_data = PyDataMem_RENEW(PyArray_DATA(npyarr->ret),
#             |                                                     ^~~~~~~~~~~
#       /private/var/folders/p1/jp0nz1s934z81bhr01h6z0lr0000gn/T/pip-build-env-b44mk95b/overlay/lib/python3.10/site-packages/numpy/_core/include/numpy/ndarraytypes.h:1508:35: note: passing argument to parameter 'arr' here
#        1508 | PyArray_DATA(const PyArrayObject *arr)
#             |                                   ^
#       pandas/_libs/src/ujson/python/JSONtoObj.c:316:18: warning: incompatible pointer types passing 'PyObject *' (aka 'struct _object *') to parameter of type 'const PyArrayObject *' (aka 'const struct tagPyArrayObject_fields *') [-Wincompatible-pointer-types]
#         316 |     PyArray_DIMS(npyarr->ret)[0] = i + 1;
#             |                  ^~~~~~~~~~~
#       /private/var/folders/p1/jp0nz1s934z81bhr01h6z0lr0000gn/T/pip-build-env-b44mk95b/overlay/lib/python3.10/site-packages/numpy/_core/include/numpy/ndarraytypes.h:1520:35: note: passing argument to parameter 'arr' here
#        1520 | PyArray_DIMS(const PyArrayObject *arr)
#             |                                   ^
#       pandas/_libs/src/ujson/python/JSONtoObj.c:318:33: warning: incompatible pointer types passing 'PyObject *' (aka 'struct _object *') to parameter of type 'const PyArrayObject *' (aka 'const struct tagPyArrayObject_fields *') [-Wincompatible-pointer-types]
#         318 |     if ((item = PyArray_GETPTR1(npyarr->ret, i)) == NULL ||
#             |                                 ^~~~~~~~~~~
#       /private/var/folders/p1/jp0nz1s934z81bhr01h6z0lr0000gn/T/pip-build-env-b44mk95b/overlay/lib/python3.10/site-packages/numpy/_core/include/numpy/ndarrayobject.h:138:57: note: expanded from macro 'PyArray_GETPTR1'
#         138 | #define PyArray_GETPTR1(obj, i) ((void *)(PyArray_BYTES(obj) + \
#             |                                                         ^~~
#       /private/var/folders/p1/jp0nz1s934z81bhr01h6z0lr0000gn/T/pip-build-env-b44mk95b/overlay/lib/python3.10/site-packages/numpy/_core/include/numpy/ndarraytypes.h:1514:36: note: passing argument to parameter 'arr' here
#        1514 | PyArray_BYTES(const PyArrayObject *arr)
#             |                                    ^
#       pandas/_libs/src/ujson/python/JSONtoObj.c:318:33: warning: incompatible pointer types passing 'PyObject *' (aka 'struct _object *') to parameter of type 'const PyArrayObject *' (aka 'const struct tagPyArrayObject_fields *') [-Wincompatible-pointer-types]
#         318 |     if ((item = PyArray_GETPTR1(npyarr->ret, i)) == NULL ||
#             |                                 ^~~~~~~~~~~
#       /private/var/folders/p1/jp0nz1s934z81bhr01h6z0lr0000gn/T/pip-build-env-b44mk95b/overlay/lib/python3.10/site-packages/numpy/_core/include/numpy/ndarrayobject.h:139:62: note: expanded from macro 'PyArray_GETPTR1'
#         139 |                                          (i)*PyArray_STRIDES(obj)[0]))
#             |                                                              ^~~
#       /private/var/folders/p1/jp0nz1s934z81bhr01h6z0lr0000gn/T/pip-build-env-b44mk95b/overlay/lib/python3.10/site-packages/numpy/_core/include/numpy/ndarraytypes.h:1526:38: note: passing argument to parameter 'arr' here
#        1526 | PyArray_STRIDES(const PyArrayObject *arr)
#             |                                      ^
#       pandas/_libs/src/ujson/python/JSONtoObj.c:319:25: warning: incompatible pointer types passing 'PyObject *' (aka 'struct _object *') to parameter of type 'PyArrayObject *' (aka 'struct tagPyArrayObject_fields *') [-Wincompatible-pointer-types]
#         319 |         PyArray_SETITEM(npyarr->ret, item, value) == -1) {
#             |                         ^~~~~~~~~~~
#       /private/var/folders/p1/jp0nz1s934z81bhr01h6z0lr0000gn/T/pip-build-env-b44mk95b/overlay/lib/python3.10/site-packages/numpy/_core/include/numpy/ndarrayobject.h:292:32: note: passing argument to parameter 'arr' here
#         292 | PyArray_SETITEM(PyArrayObject *arr, char *itemptr, PyObject *v)
#             |                                ^
#       6 warnings and 1 error generated.
#       error: command '/usr/bin/clang' failed with exit code 1
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for pandas
# Failed to build pandas
# ERROR: Could not build wheels for pandas, which is required to install pyproject.toml-based projects

# %% [markdown]
# 1. Fetch the artifact we just created (sample.csv) from W&B and read it with pandas:

# %%
import wandb
import pandas as pd
# Note that we use save_code=True in the call to wandb.init so the notebook is uploaded and versioned by W&B
run = wandb.init(project="nyc_airbnb", group="eda", save_code=True)
local_path = wandb.use_artifact("sample.csv:latest").file()
df = pd.read_csv(local_path)
# Out:
# wandb: Currently logged in as: jschl34 (jschl34-western-governors-university). Use `wandb login --relogin` to force relogin
# wandb version 0.18.7 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.0
# Run data is saved locally in <code>/Users/jennschlenker/D501_MachineLearningDevOps/Project-Build-an-ML-Pipeline-Starter/src/eda/wandb/run-20241118_053414-nq1ra9ks</code>
# Syncing run <strong><a href='https://wandb.ai/jschl34-western-governors-university/nyc_airbnb/runs/nq1ra9ks' target="_blank">divine-spaceship-2</a></strong> to <a href='https://wandb.ai/jschl34-western-governors-university/nyc_airbnb' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/jschl34-western-governors-university/nyc_airbnb' target="_blank">https://wandb.ai/jschl34-western-governors-university/nyc_airbnb</a>
#  View run at <a href='https://wandb.ai/jschl34-western-governors-university/nyc_airbnb/runs/nq1ra9ks' target="_blank">https://wandb.ai/jschl34-western-governors-university/nyc_airbnb/runs/nq1ra9ks</a>

# %% [markdown]
# 2. Explore the data in df

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              20000 non-null  int64
#  1   name                            19993 non-null  object
#  2   host_id                         20000 non-null  int64
#  3   host_name                       19992 non-null  object
#  4   neighbourhood_group             20000 non-null  object
#  5   neighbourhood                   20000 non-null  object
#  6   latitude                        20000 non-null  float64
#  7   longitude                       20000 non-null  float64
#  8   room_type                       20000 non-null  object
#  9   price                           20000 non-null  int64
#  10  minimum_nights                  20000 non-null  int64
#  11  number_of_reviews               20000 non-null  int64
#  12  last_review                     15877 non-null  object
#  13  reviews_per_month               15877 non-null  float64
#  14  calculated_host_listings_count  20000 non-null  int64
#  15  availability_365                20000 non-null  int64
# dtypes: float64(3), int64(7), object(6)
# memory usage: 2.4+ MB

# %%
df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  2.000000e+04  2.000000e+04  20000.000000  20000.000000  20000.000000
# mean   1.892380e+07  6.746034e+07     40.728455    -73.952125    153.269050
# std    1.101223e+07  7.857936e+07      0.054755      0.046559    243.325609
# min    2.539000e+03  2.571000e+03     40.508730    -74.239140      0.000000
# 25%    9.393540e+06  7.853718e+06     40.689420    -73.983030     69.000000
# 50%    1.952117e+07  3.111431e+07     40.722730    -73.955640    105.000000
# 75%    2.912936e+07  1.068426e+08     40.762990    -73.936380    175.000000
# max    3.648561e+07  2.742733e+08     40.913060    -73.717950  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    20000.000000       20000.000000       15877.000000
# mean         6.992100          23.274100           1.377446
# std         21.645449          44.927793           1.683006
# min          1.000000           0.000000           0.010000
# 25%          1.000000           1.000000           0.190000
# 50%          2.000000           5.000000           0.720000
# 75%          5.000000          23.000000           2.010000
# max       1250.000000         607.000000          27.950000
#
#        calculated_host_listings_count  availability_365
# count                    20000.000000      20000.000000
# mean                         6.955450        112.901200
# std                         32.433831        131.762226
# min                          1.000000          0.000000
# 25%                          1.000000          0.000000
# 50%                          1.000000         44.000000
# 75%                          2.000000        229.000000
# max                        327.000000        365.000000

# %%
df.head()
# Out:
#          id                                               name    host_id  \
# 0   9138664                Private Lg Room 15 min to Manhattan   47594947
# 1  31444015  TIME SQUARE CHARMING ONE BED IN HELL'S KITCHEN...    8523790
# 2   8741020  Voted #1 Location Quintessential 1BR W Village...   45854238
# 3  34602077  Spacious 1 bedroom apartment 15min from Manhattan  261055465
# 4  23203149   Big beautiful bedroom in huge Bushwick apartment     143460
#
#   host_name neighbourhood_group   neighbourhood  latitude  longitude  \
# 0      Iris              Queens       Sunnyside  40.74271  -73.92493
# 1    Johlex           Manhattan  Hell's Kitchen  40.76682  -73.98878
# 2      John           Manhattan    West Village  40.73631  -74.00611
# 3     Regan              Queens         Astoria  40.76424  -73.92351
# 4     Megan            Brooklyn        Bushwick  40.69839  -73.92044
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room     74               2                  6  2019-05-26
# 1  Entire home/apt    170               3                  0         NaN
# 2  Entire home/apt    245               3                 51  2018-09-19
# 3  Entire home/apt    125               3                  1  2019-05-24
# 4     Private room     65               2                  8  2019-06-23
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.13                               1                 5
# 1                NaN                               1               188
# 2               1.12                               1                 0
# 3               0.65                               1                13
# 4               0.52                               2                 8

# %% [markdown]
# 3. What do you notice in the data? Look around and see what you can find.
#
# > For example, there are missing values in a few columns and the column `last_review` is a date but it is in string format. Look also at the `price` column, and note the outliers. There are some zeros and some very high prices. After talking to your stakeholders, you decide to consider from a minimum of `$10` to a maximum of `$350` per night.

# %% [markdown]
# 4. Fix some of the little problems we have found in the data with the following code:

# %%
# Drop outliers
min_price = 10
max_price = 350
idx = df['price'].between(min_price, max_price)
df = df[idx].copy()
# Convert last_review to datetime
df['last_review'] = pd.to_datetime(df['last_review'])

# %% [markdown]
# Note how we did not impute missing values. We will do that in the inference pipeline, so we will be able to handle missing values also in production.

# %% [markdown]
# 5. Check with df.info() that all obvious problems have been solved

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19001 entries, 0 to 19999
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              19001 non-null  int64
#  1   name                            18994 non-null  object
#  2   host_id                         19001 non-null  int64
#  3   host_name                       18993 non-null  object
#  4   neighbourhood_group             19001 non-null  object
#  5   neighbourhood                   19001 non-null  object
#  6   latitude                        19001 non-null  float64
#  7   longitude                       19001 non-null  float64
#  8   room_type                       19001 non-null  object
#  9   price                           19001 non-null  int64
#  10  minimum_nights                  19001 non-null  int64
#  11  number_of_reviews               19001 non-null  int64
#  12  last_review                     15243 non-null  datetime64[ns]
#  13  reviews_per_month               15243 non-null  float64
#  14  calculated_host_listings_count  19001 non-null  int64
#  15  availability_365                19001 non-null  int64
# dtypes: datetime64[ns](1), float64(3), int64(7), object(5)
# memory usage: 2.5+ MB

# %% [markdown]
# 6. Terminate the run by running `run.finish()`

# %%
run.finish()
# Out:
#  View run <strong style="color:#cdcd00">divine-spaceship-2</strong> at: <a href='https://wandb.ai/jschl34-western-governors-university/nyc_airbnb/runs/nq1ra9ks' target="_blank">https://wandb.ai/jschl34-western-governors-university/nyc_airbnb/runs/nq1ra9ks</a><br/> View job at <a href='https://wandb.ai/jschl34-western-governors-university/nyc_airbnb/jobs/QXJ0aWZhY3RDb2xsZWN0aW9uOjQ5Njg4MjE1Mw==/version_details/v0' target="_blank">https://wandb.ai/jschl34-western-governors-university/nyc_airbnb/jobs/QXJ0aWZhY3RDb2xsZWN0aW9uOjQ5Njg4MjE1Mw==/version_details/v0</a><br/>Synced 7 W&B file(s), 0 media file(s), 3 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20241118_053414-nq1ra9ks/logs</code>

# %% [markdown]
# 7. Save the notebook.
